# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9590cf4e-0bc1-4499-9dfa-483dd88c252a                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  *   **Solid-State Batteries are Nearing Commercialization:** Next-generation solid-state batteries, offering   │
# │  higher energy density, faster charging, and improved safety compared to current lithium-ion batteries, are     │
# │  expected to begin appearing in production EVs by the mid-to-late 2020s, potentially revolutionizing range and  │
# │  charging times.                                                                                                │
# │  *   **Vehicle-to-Grid (V2G) Technology is Gaining Traction:** The future of EVs includes their integration     │
# │  into the power grid, allowing them to not only charge but also discharge electricity back into homes or the    │
# │  grid during peak demand or power outages, turning EVs into mobile energy storage units and enhancing grid      │
# │  stability.                                                                                                     │
# │  *   **Charging Infrastructure is Rapidly Expanding and Diversifying:** Beyond public fast chargers, the        │
# │  future will see a significant increase in destination charging (e.g., at workplaces, shopping centers,         │
# │  hotels) and smart home charging solutions, making EV ownership more convenient and accessible, with a focus    │
# │  on ultra-fast charging (350 kW+) becoming more common.                                                         │
# │  *   **Autonomous Driving and Electrification are Converging:** The development of fully autonomous vehicles    │
# │  is intrinsically linked with electric powertrains, as EVs offer simpler mechanical structures and easier       │
# │  integration of advanced sensor and computing systems, paving the way for a future dominated by self-driving    │
# │  electric robotaxis and delivery services.                                                                      │
# │  *   **Sustainable Sourcing and Recycling of Materials are Becoming Critical:** As EV production scales,        │
# │  there's an increasing focus on developing more sustainable methods for sourcing critical battery materials     │
# │  (like lithium, cobalt, nickel) and establishing robust recycling infrastructure to recover these materials,    │
# │  reducing environmental impact and reliance on new mining.                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 3c09603b-2f92-45f9-a6c7-2a409a21c0af                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is electrifying! Get ready for game-changing solid-state batteries arriving    │
# │  mid-to-late 2020s, promising superior range and lightning-fast charging. EVs will transform into mobile        │
# │  powerhouses with Vehicle-to-Grid (V2G) technology, supporting homes and the grid. Charging infrastructure is   │
# │  rapidly expanding, with ultra-fast public chargers, widespread destination charging, and smart home solutions  │
# │  making ownership seamless. Expect autonomous driving and electrification to converge, bringing self-driving    │
# │  electric robotaxis closer to reality. Crucially, the industry is prioritizing sustainable material sourcing    │
# │  and robust recycling, ensuring a greener EV ecosystem. The road ahead for EVs is innovative, integrated, and   │
# │  incredibly exciting!                                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: becac81e-a6a5-4f28-96da-828b69246515                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 9590cf4e-0bc1-4499-9dfa-483dd88c252a                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: The future of electric vehicles is electrifying! Get ready for game-changing solid-state         │
# │  batteries arriving mid-to-late 2020s, promising superior range and lightning-fast charging. EVs will           │
# │  transform into mobile powerhouses with Vehicle-to-Grid (V2G) technology, supporting homes and the grid.        │
# │  Charging infrastructure is rapidly expanding, with ultra-fast public chargers, widespread destination          │
# │  charging, and smart home solutions making ownership seamless. Expect autonomous driving and electrification    │
# │  to converge, bringing self-driving electric robotaxis closer to reality. Crucially, the industry is            │
# │  prioritizing sustainable material sourcing and robust recycling, ensuring a greener EV ecosystem. The road     │
# │  ahead for EVs is innovative, integrated, and incredibly exciting!                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='The future of electric vehicles is electrifying! Get ready for game-changing solid-state batteries arriving mid-to-late 2020s, promising superior range and lightning-fast charging. EVs will transform into mobile powerhouses with Vehicle-to-Grid (V2G) technology, supporting homes and the grid. Charging infrastructure is rapidly expanding, with ultra-fast public chargers, widespread destination charging, and smart home solutions making ownership seamless. Expect autonomous driving and electrification to converge, bringing self-driving electric robotaxis closer to reality. Crucially, the industry is prioritizing sustainable material sourcing and robust recycling, ensuring a greener EV ecosystem. The road ahead for EVs is innovative, integrated, and incredibly exciting!', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles.', name=None, expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw="*   **Solid-State Batteries are Nearing Commercialization:** Next-generation solid-state batteries, offering higher energy density, faster charging, and improved safety compared to current lithium-ion batteries, are expected to begin appearing in production EVs by the mid-to-late 2020s, potentially revolutionizing range and charging times.\n*   **Vehicle-to-Grid (V2G) Technology is Gaining Traction:** The future of EVs includes their integration into the power grid, allowing them to not only charge but also discharge electricity back into homes or the grid during peak demand or power outages, turning EVs into mobile energy storage units and enhancing grid stability.\n*   **Charging Infrastructure is Rapidly Expanding and Diversifying:** Beyond public fast chargers, the future will see a significant increase in destination charging (e.g., at workplaces, shopping centers, hotels) and smart home charging solutions, making EV ownership more convenient and accessible, with a focus on ultra-fast charging (350 kW+) becoming more common.\n*   **Autonomous Driving and Electrification are Converging:** The development of fully autonomous vehicles is intrinsically linked with electric powertrains, as EVs offer simpler mechanical structures and easier integration of advanced sensor and computing systems, paving the way for a future dominated by self-driving electric robotaxis and delivery services.\n*   **Sustainable Sourcing and Recycling of Materials are Becoming Critical:** As EV production scales, there's an increasing focus on developing more sustainable methods for sourcing critical battery materials (like lithium, cobalt, nickel) and establishing robust recycling infrastructure to recover these materials, reducing environmental impact and reliance on new mining.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>), TaskOutput(description='Write a 100-word blog post summary about The future of electrical vehicles using the facts from the research.', name=None, expected_output='A blog post summary', summary='Write a 100-word blog post summary about The future of...', raw='The future of electric vehicles is electrifying! Get ready for game-changing solid-state batteries arriving mid-to-late 2020s, promising superior range and lightning-fast charging. EVs will transform into mobile powerhouses with Vehicle-to-Grid (V2G) technology, supporting homes and the grid. Charging infrastructure is rapidly expanding, with ultra-fast public chargers, widespread destination charging, and smart home solutions making ownership seamless. Expect autonomous driving and electrification to converge, bringing self-driving electric robotaxis closer to reality. Crucially, the industry is prioritizing sustainable material sourcing and robust recycling, ensuring a greener EV ecosystem. The road ahead for EVs is innovative, integrated, and incredibly ex ...
